# %%
import word_score
import kmeans
text="It was horrible"
score=word_score.get_tuple(text)
score
# Out:
# it {'neg_score': '0', 'pos_score': '0'}
# horribl {'neg_score': '0.625', 'pos_score': '0'}
# (0.0, 0.62, 0.0)

# %%
import csv
rulebase=[]
with open("rulebase.csv") as csv_file:
    reader=csv.reader(csv_file)
    rulebase.append(next(reader))
    for row in reader:
        c=row[-1]
        row=[float(val) for val in row[:-1]]+[row[-1]]
        rulebase.append(row)
rulebase[:]
# Out:
# [['pos_score', 'neg_score', 'ratio(pos/neg)', 'class'],
#  [0.5, 0.0, 5.0, 'n'],
#  [0.88, 0.0, 5.0, 'n'],
#  [1.0, 0.0, 5.0, 'n'],
#  [0.62, 0.0, 5.0, 'n'],
#  [1.62, 0.0, 5.0, 'n'],
#  [2.12, 0.25, 5.0, 'n'],
#  [3.12, 0.0, 5.0, 'n'],
#  [0.5, 0.25, 2.0, 'b'],
#  [0.62, 1.0, 2.0, 'b'],
#  [1.12, 0.62, 2.0, 'b'],
#  [1.38, 0.62, 3.0, 'b'],
#  [0.38, 0.75, 1.0, 'b'],
#  [0.0, 0.5, 0.0, 'b'],
#  [0.38, 0.75, 2.0, 'b'],
#  [0.0, 0.88, 0.0, 'b'],
#  [0.38, 2.0, 0.67, 'b']]

# %%
neighbours=[]
def knn(k):
    
    output=None
    distance={}
    for i in range(len(rulebase[1:])):
        p1=rulebase[i+1][:-1]
        
        distance[i+1]=round(kmeans.distance(len(p1),p1,score),2)
    #print(distance,"\n")
    distance = sorted(distance.items(), key=lambda x: x[1])
    
    #print(distance,"\n")
    distance=distance[:k]
    print(distance,"\n")
    global neighbours
    neighbours=[rulebase[i[0]][:-1] for i in distance]
    print(neighbours)
    g_count=b_count=n_count=0
    
    for i in distance:
        if rulebase[i[0]][-1]=='g':
            g_count+=1
        elif rulebase[i[0]][-1]=='b':
            b_count+=1
        elif rulebase[i[0]][-1]=='n':
            n_count+=1
       
        if(g_count== max(g_count,b_count,n_count)):
            output='g'
        if(b_count== max(g_count,b_count,n_count)):
            output='b'
       
        if(n_count== max(g_count,b_count,n_count)):
            output='n'
    print(output)

# %%
knn(4)
# Out:
# [(13, 0.12), (15, 0.26), (12, 1.08), (16, 1.58)]
#
# [[0.0, 0.5, 0.0], [0.0, 0.88, 0.0], [0.38, 0.75, 1.0], [0.38, 2.0, 0.67]]
# b

# %%
g=[tuple(row[:-1]) for row in rulebase if row[-1]=='g']
b=[tuple(row[:-1]) for row in rulebase if row[-1]=='b']
n=[tuple(row[:-1]) for row in rulebase if row[-1]=='n']
g,b,n,neighbours
# Out:
# ([],
#  [(0.5, 0.25, 2.0),
#   (0.62, 1.0, 2.0),
#   (1.12, 0.62, 2.0),
#   (1.38, 0.62, 3.0),
#   (0.38, 0.75, 1.0),
#   (0.0, 0.5, 0.0),
#   (0.38, 0.75, 2.0),
#   (0.0, 0.88, 0.0),
#   (0.38, 2.0, 0.67)],
#  [(0.5, 0.0, 5.0),
#   (0.88, 0.0, 5.0),
#   (1.0, 0.0, 5.0),
#   (0.62, 0.0, 5.0),
#   (1.62, 0.0, 5.0),
#   (2.12, 0.25, 5.0),
#   (3.12, 0.0, 5.0)],
#  [[0.0, 0.5, 0.0], [0.0, 0.88, 0.0], [0.38, 0.75, 1.0], [0.38, 2.0, 0.67]])

# %%
colors=["#0000FF", "#00FF00", "#FF0066"]

# %matplotlib inline
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import random
fig = pyplot.figure(figsize=(15,10))
ax = fig.add_subplot(111, projection='3d')

if len(g)>0:
    ax.scatter(*zip(*g),label='g',color="red")
if len(b)>0:
    ax.scatter(*zip(*b),label='b',color="blue")
if len(n)>0:
    ax.scatter(*zip(*n),label='n',color="green")
ax.scatter(*zip(*neighbours),label='neighbours',marker='x',color="black",s=50)
ax.scatter(score[0],score[1],score[2],label="new point",color="yellow")

#ax.scatter(0,0,10,marker='x')
pyplot.xlim(0, 5)
pyplot.ylim(0, 5)

ax.legend()
